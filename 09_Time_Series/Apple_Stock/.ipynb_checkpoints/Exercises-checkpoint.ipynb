# %% [markdown]
# # Apple Stock

# %% [markdown]
# ### Introduction:
#
# We are going to use Apple's stock price.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv)

# %% [markdown]
# ### Step 3. Assign it to a variable apple

# %%
apple = pd.read_csv("appl_1980_2014.csv")
apple
# Out:
#             Date   Open   High    Low  Close     Volume  Adj Close
# 0     2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1     2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2     2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3     2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4     2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...    ...    ...    ...    ...        ...        ...
# 8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# ### Step 4.  Check out the type of the columns

# %%
apple.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %% [markdown]
# ### Step 5. Transform the Date column as a datetime type

# %%
apple["Date"] = apple["Date"].astype("datetime64")
apple
# Out:
#            Date   Open   High    Low  Close     Volume  Adj Close
# 0    2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1    2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2    2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3    2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4    2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...         ...    ...    ...    ...    ...        ...        ...
# 8460 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %%
apple = pd.read_csv("appl_1980_2014.csv",parse_dates=["Date"])
apple
# Out:
#            Date   Open   High    Low  Close     Volume  Adj Close
# 0    2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1    2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2    2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3    2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4    2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...         ...    ...    ...    ...    ...        ...        ...
# 8460 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# ### Step 6.  Set the date as the index

# %%
apple = apple.set_index("Date")

# %% [markdown]
# ### Step 7.  Is there any duplicate dates?

# %%
len(apple) - len(apple.drop_duplicates())
#apple.index.is_unique
# Out:
# True

# %% [markdown]
# ### Step 8.  Ops...it seems the index is from the most recent date. Make the first entry the oldest date.

# %%
apple = apple.sort_index()
apple
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# ...           ...    ...    ...    ...        ...        ...
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
#
# [8465 rows x 6 columns]

# %% [markdown]
# ### Step 9. Get the last business day of each month

# %%
apple.resample("BM").mean()
# Out:
#                   Open        High         Low       Close        Volume  \
# Date
# 1980-12-31   30.481538   30.567692   30.443077   30.443077  2.586252e+07
# 1981-01-30   31.754762   31.826667   31.654762   31.654762  7.249867e+06
# 1981-02-27   26.480000   26.572105   26.407895   26.407895  4.231832e+06
# 1981-03-31   24.937727   25.016818   24.836364   24.836364  7.962691e+06
# 1981-04-30   27.286667   27.368095   27.227143   27.227143  6.392000e+06
# ...                ...         ...         ...         ...           ...
# 2014-03-31  533.593333  536.453810  530.070952  533.214286  5.954403e+07
# 2014-04-30  540.081905  544.349048  536.262381  541.074286  7.660787e+07
# 2014-05-30  601.301905  606.372857  598.332857  603.195714  6.828177e+07
# 2014-06-30  222.360000  224.084286  220.735714  222.658095  5.745506e+07
# 2014-07-31   94.294000   95.004000   93.488000   94.470000  4.218366e+07
#
#             Adj Close
# Date
# 1980-12-31   0.473077
# 1981-01-30   0.493810
# ...

# %% [markdown]
# ### Step 10.  What is the difference in days between the first day and the oldest

# %%
apple.index.max()-apple.index.min()
# Out:
# Timedelta('12261 days 00:00:00')

# %% [markdown]
# ### Step 11.  How many months in the data we have?

# %%
len(apple.resample("BM").mean())
# Out:
# 404

# %% [markdown]
# ### Step 12. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
plt.plot(apple["Adj Close"])
plt.figure(figsize=(13.5,9))
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
# downsample the apple data to be every month and get the min,max,std of each company for every month
dictionary = dict()
for i in apple.columns:
    dictionary[i] = ['min','max','std']
apple.resample("M").agg(dictionary)
# Out:
#               Open                        High                         Low  \
#                min     max         std     min     max         std     min
# Date
# 1980-12-31   25.37   36.00    3.844498   25.37   36.13    3.844273   25.25
# 1981-01-31   28.50   34.50    1.362749   28.50   34.75    1.410030   28.25
# 1981-02-28   24.00   28.75    1.402541   24.00   28.87    1.444448   23.75
# 1981-03-31   21.87   26.75    1.572238   21.87   27.00    1.579024   21.62
# 1981-04-30   24.38   29.25    1.351981   24.38   29.37    1.370196   24.25
# ...            ...     ...         ...     ...     ...         ...     ...
# 2014-03-31  523.42  546.52    5.719830  529.97  549.00    5.132560  522.81
# 2014-04-30  518.05  593.74   23.881856  521.09  599.43   25.896587  511.33
# 2014-05-31  584.54  637.98   14.672119  586.25  644.17   15.609068  580.33
# 2014-06-30   90.21  649.90  238.805672   90.70  651.26  240.800419   89.65
# ...
