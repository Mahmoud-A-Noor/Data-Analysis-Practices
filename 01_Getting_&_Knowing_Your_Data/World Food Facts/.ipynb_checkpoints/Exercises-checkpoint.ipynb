# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Step 2. Download the dataset to your computer and unzip it.

# %% [markdown]
# ### Step 3. Use the tsv file and assign it to a dataframe called food

# %%
import pandas as pd
import numpy as np
food = pd.read_csv("en.openfoodfacts.org.products.tsv",sep="\t")
food
# Out:
# c:\users\mahmo\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                  code                                                url  ... glycemic-index_100g water-hardness_100g
# 0                3087  http://world-en.openfoodfacts.org/product/0000...  ...                 NaN                 NaN
# 1                4530  http://world-en.openfoodfacts.org/product/0000...  ...                 NaN                 NaN
# 2                4559  http://world-en.openfoodfacts.org/product/0000...  ...                 NaN                 NaN
# 3               16087  http://world-en.openfoodfacts.org/product/0000...  ...                 NaN                 NaN
# 4               16094  http://world-en.openfoodfacts.org/product/0000...  ...                 NaN                 NaN
# ...               ...                                                ...  ...                 ...                 ...
# 356022       99567453  http://world-en.openfoodfacts.org/product/9956...  ...                 NaN                 NaN
# 356023  9970229501521  http://world-en.openfoodfacts.org/product/9970...  ...                 NaN                 NaN
# 356024  9977471758307  http://world-en.openfoodfacts.org/product/9977...  ...                 NaN                 NaN
# 356025  9980282863788  http://world-en.openfoodfacts.org/product/9980...  ...                 NaN                 NaN
# 356026   999990026839  http://world-en.openfoodfacts.org/product/9999...  ...                 NaN                 NaN
#
# [356027 rows x 163 columns]

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
food.head(5)
# Out:
#     code                                                url  ... glycemic-index_100g water-hardness_100g
# 0   3087  http://world-en.openfoodfacts.org/product/0000...  ...                 NaN                 NaN
# 1   4530  http://world-en.openfoodfacts.org/product/0000...  ...                 NaN                 NaN
# 2   4559  http://world-en.openfoodfacts.org/product/0000...  ...                 NaN                 NaN
# 3  16087  http://world-en.openfoodfacts.org/product/0000...  ...                 NaN                 NaN
# 4  16094  http://world-en.openfoodfacts.org/product/0000...  ...                 NaN                 NaN
#
# [5 rows x 163 columns]

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
food.shape[0]
# Out:
# 356027

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
food.shape[1]
# Out:
# 163

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
food.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %%
food.columns[104]
# Out:
# '-fructose_100g'

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %%
food[food.columns[104]].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %%
food.index
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?

# %%
food["product_name"][food.index == 19]
# Out:
# 19    Organic Oat Groats
# Name: product_name, dtype: object
